// %% [markdown]
// [![Binder](img/badge-binder.svg)](https://mybinder.org/v2/gh/nhirschey/teaching/gh-pages?filepath=assignment-signal-portfolio.ipynb)&emsp;
// [![Script](img/badge-script.svg)](/Teaching//assignment-signal-portfolio.fsx)&emsp;
// [![Notebook](img/badge-notebook.svg)](/Teaching//assignment-signal-portfolio.ipynb)
//
// Student Name | Student Number
// --- | --- | ---
// **1** | &#32; | &#32;
// **2** | &#32; | &#32;
//
//
// **Signal Name (e.g., Book to Market):**
//
// **Signal Code (e.g., be_me):**
//
// This is an assignment. You may work in pairs (two students) using either student's signal to answer the below questions.  You will find sections labeled **Task** asking you to do each piece of analysis. Please make sure that you complete all of these tasks. Make use of the course resources and example code on the course website. It should be possible to complete all the requested tasks using information given below or somewhere on the course website.

// %%
#r "nuget:FSharp.Data"
#r "nuget: FSharp.Stats"
#r "nuget: Plotly.NET, 2.0.0-preview.17"
// Out:
// Microsoft.DotNet.Interactive.InstallPackagesMessage

// %%
#r "nuget: Plotly.NET.Interactive, 2.0.0-preview.17"
// Out:
// Microsoft.DotNet.Interactive.InstallPackagesMessage

// %%
open System
open FSharp.Data
open Plotly.NET
open FSharp.Stats

// %%
// Set dotnet interactive formatter to plaintext
Formatter.Register(fun (x:obj) (writer: TextWriter) -> fprintfn writer "%120A" x )
Formatter.SetPreferredMimeTypesFor(typeof<obj>, "text/plain")
// Make plotly graphs work with interactive plaintext formatter
Formatter.SetPreferredMimeTypesFor(typeof<GenericChart.GenericChart>,"text/html")

// %% [markdown]
// ## Load Data
//
// First, make sure that you're referencing the correct files.
//
// Here I'm assuming that you have a class folder with this notebook and a `data` folder inside of it. The folder hierarchy would look like below where you
// have the below files and folders accessible:
//
// ```code
// /class
//     Portfolio.fsx
//     Common.fsx
//     notebook.ipynb
//     /data
//         id_and_return_data.csv
//         zero_trades_252d.csv
//
// ```

// %%
let [<Literal>] ResolutionFolder = __SOURCE_DIRECTORY__
Environment.CurrentDirectory <- ResolutionFolder

#load "Portfolio.fsx"
open Portfolio

#load "Common.fsx"
open Common

// %% [markdown]
// ### Data files
//
// We assume the `id_and_return_data.csv` file and the signal csv file  are in the `data` folder. In this example the signal file is `zero_trades_252d.csv`. You should replace that file name with your signal file name.

// %%
let [<Literal>] IdAndReturnsFilePath = "data/id_and_return_data.csv"
let [<Literal>] MySignalFilePath = ""
let strategyName = ""

// %% [markdown]
// If my paths are correct, then this code should read the first few lines of the files.
// If it doesn't show the first few lines, fix the above file paths.

// %%
IO.File.ReadLines(IdAndReturnsFilePath) |> Seq.truncate 5
// Out:
// seq
//   ["id(string),eom(date),source(string),sizeGrp(string),obsMain(string),exchMain(string),primarySec(bool),gvkey(string),iid(string),permno(int Option),permco(int Option),excntry(string),curcd(string),fx(string),common(bool),compTpci(string),crspShrcd(int Option),compExchg(string),crsp_exchcd(int Option),adjfct(float Option),shares(float Option),gics(int Option),sic(int Option),naics(int Option),ff49(int Option),ret(float Option),retExc(float Option),prc(float Option),marketEquity(float Option)";
//    "crsp_86432,2000-01-31T00:00:00.0000000,CRSP,micro,1,1,true,115876,01,86432,16313,USA,USD,1,true,,11,,3,2,5.218,40101010,6020,522110,45,-0.003906,-0.00824925,15.9375,83.161875";
//    "crsp_85640,2000-01-31T00:00:00.0000000,CRSP,small,1,1,true,002193,01,85640,20300,USA,USD,1,true,,11,,1,1,102.496,35102020,8051,623110,11,-0.157143,-0.161485863,3.6875,377.954";
//    "crsp_86430,2000-01-31T00:00:00.0000000,CRSP,micro,1,1,true,115946,01,86430,16319,USA,USD,1,true,,11,,3,1,10.764,45103010,7372,511210,36,0.285714,0.2813712985,3.9375,42.38325";
//    ...]

// %%
IO.File.ReadLines(MySignalFilePath) |> Seq.truncate 5
// Out:
// seq
//   ["id(string),eom(date),signal(float option)"; "comp_001034_01,2008-12-31T00:00:00.0000000,5";
//    "comp_001043_01,2000-01-31T00:00:00.0000000,5"; "comp_001076_02,2010-12-31T00:00:00.0000000,"; ...]

// %% [markdown]
// Ok, now assuming those paths were correct the below code will work.
// I will put all this prep code in one block so that it is easy to run.

// %%
/// Type for Id and returns csv data
type IdAndReturnsType = 
    CsvProvider<Sample=IdAndReturnsFilePath,
                // The schema parameter is not required,
                // but I am using it to override some column types
                // to make filtering easier.
                // If I didn't do this these particular columns 
                // would have strings of "1" or "0", but explicit boolean is nicer.
                Schema="obsMain(string)->obsMain=bool,exchMain(string)->exchMain=bool",
                ResolutionFolder=ResolutionFolder>

/// Type for the signal data
type MySignalType = 
    CsvProvider<MySignalFilePath,
                ResolutionFolder=ResolutionFolder>

/// Id and returns data indexed by security id and month
let msfBySecurityIdAndMonth =
    IdAndReturnsType.GetSample().Rows
    |> Seq.map(fun row -> 
        let id = Other row.Id
        let month = DateTime(row.Eom.Year,row.Eom.Month,1)
        let key = id, month
        key, row)
    |> Map    

/// Signal data indexed by security id and month
let signalBySecurityIdAndMonth =
    MySignalType.GetSample().Rows
    |> Seq.choose(fun row -> 
        // we'll use choose to drop the security if the signal is None.
        // The signal is None when it is missing.
        match row.Signal with
        | None -> None // choose will drop these None observations
        | Some signal ->
            let id = Other row.Id
            let month = DateTime(row.Eom.Year,row.Eom.Month,1)
            let key = id, month
            // choose will convert Some(key,signal) into
            // (key,signal) and keep that.
            Some (key, signal))
    |> Map    

/// Investment universe for each month, indexed by month.
let securitiesByFormationMonth =
    msfBySecurityIdAndMonth
    |> Map.values
    |> Seq.groupBy(fun x -> DateTime(x.Eom.Year, x.Eom.Month,1))
    |> Seq.map(fun (ym, obsThisMonth) -> 
        let idsThisMonth = [ for x in obsThisMonth do Other x.Id ]
        ym, idsThisMonth)
    |> Map

/// Function to get investment universe for a month.
let getInvestmentUniverse formationMonth =
    match Map.tryFind formationMonth securitiesByFormationMonth with
    | Some securities -> 
        { FormationMonth = formationMonth 
          Securities = securities }
    | None -> failwith $"{formationMonth} is not in the date range"
   
/// Function to get signal for entire investment universe.
let getMySignals (investmentUniverse: InvestmentUniverse) =
    let getMySignal (securityId, formationMonth) =
        match Map.tryFind (securityId, formationMonth) signalBySecurityIdAndMonth with
        | None -> None
        | Some signal ->
            Some { SecurityId = securityId 
                   // if a high signal means low returns,
                   // use `-signal` here instead of `signal`
                   Signal = signal }
    let listOfSecuritySignals =
        investmentUniverse.Securities
        |> List.choose(fun security -> 
            getMySignal (security, investmentUniverse.FormationMonth))    
    
    { FormationMonth = investmentUniverse.FormationMonth 
      Signals = listOfSecuritySignals }


/// Function to get market cap for security in a month.
let getMarketCap (security, formationMonth) =
    match Map.tryFind (security, formationMonth) msfBySecurityIdAndMonth with
    | None -> None
    | Some row -> 
        match row.MarketEquity with
        | None -> None
        | Some me -> Some (security, me)

/// Function to get returns for a security in a month.
let getSecurityReturn (security, formationMonth) =
    // If the security has a missing return, assume that we got 0.0.
    // Note: If we were doing excess returns, we would need 0.0 - rf.
    let missingReturn = 0.0
    match Map.tryFind (security, formationMonth) msfBySecurityIdAndMonth with
    | None -> security, missingReturn
    | Some x ->  
        match x.Ret with 
        | None -> security, missingReturn
        | Some r -> security, r

let isObsMain (security, formationMonth) =
    match Map.tryFind (security, formationMonth) msfBySecurityIdAndMonth with
    | None -> false
    | Some row -> row.ObsMain

let isPrimarySecurity (security, formationMonth) =
    match Map.tryFind (security, formationMonth) msfBySecurityIdAndMonth with
    | None -> false
    | Some row -> row.PrimarySec

let isCommonStock (security, formationMonth) =
    match Map.tryFind (security, formationMonth) msfBySecurityIdAndMonth with
    | None -> false
    | Some row -> row.Common

let isExchMain (security, formationMonth) =
    match Map.tryFind (security, formationMonth) msfBySecurityIdAndMonth with
    | None -> false
    | Some row -> row.ExchMain

let hasMarketEquity (security, formationMonth) =
    match Map.tryFind (security, formationMonth) msfBySecurityIdAndMonth with
    | None -> false
    | Some row -> row.MarketEquity.IsSome

/// Data filters
let myFilters securityAndFormationMonth =
    isObsMain securityAndFormationMonth &&
    isPrimarySecurity securityAndFormationMonth &&
    isCommonStock securityAndFormationMonth &&
    isExchMain securityAndFormationMonth &&
    isExchMain securityAndFormationMonth &&
    hasMarketEquity securityAndFormationMonth

/// Function to filter investment universe by filters.
let doMyFilters (universe:InvestmentUniverse) =
    let filtered = 
        universe.Securities
        // my filters expect security, formationMonth
        |> List.map(fun security -> security, universe.FormationMonth)
        // do the filters
        |> List.filter myFilters
        // now convert back from security, formationMonth -> security
        |> List.map fst
    { universe with Securities = filtered }

/// Months in the sample where we can form portfolios.
let sampleMonths = 
    let startSample = 
        msfBySecurityIdAndMonth.Keys
        |> Seq.map(fun (id, dt) -> dt)
        |> Seq.min
    let endSample = 
        let lastMonthWithData = 
            msfBySecurityIdAndMonth.Keys
            |> Seq.map(fun (id, dt) -> dt)
            |> Seq.max
        // The end of sample is the last month when we have returns.
        // So the last month when we can form portfolios is one month
        // before that.
        lastMonthWithData.AddMonths(-1) 
    getSampleMonths (startSample, endSample)

// %% [markdown]
// ## Start of assignment
//
// > **Task:** Complete the below function. It should take a month, a strategy name, and a number `n` of portfolios as input. The output should be a list of assigned portfolios, where stocks are assigned to `n` portfolios by sorts on the signal. I've included type signatures to constrain the output to the correct type.
// >

// %%
let formAssignedPortfolios (ym: DateTime) (strategyName: string) (n: int) : list<AssignedPortfolio> =
    ym
    |> getInvestmentUniverse
    |> doMyFilters
    |> getMySignals
    |> assignSignalSort strategyName n


//                                                              Signal = 1.0 }; { SecurityId = Other "crsp_80265"
//                                                                                Signal = 1.0 }; ...] };
//  { PortfolioId = Indexed { Index = 2
//                            Name = "Piotroski F-Score" }
//    FormationMonth = 3/1/2000 12:00:00 AM
//    Signals =
//     [{ SecurityId = Other "crsp_11426"
//        Signal = 5.0 }; { SecurityId = Other "crsp_11456"
//                          Signal = 5.0 }; { SecurityId = Other "crsp_11533"
//                                            Signal = 5.0 }; { SecurityId = Other "crsp_11552"
//                                                              Signal = 5.0 }; { SecurityId = Other "crsp_11581"
//                                                                                Signal = 5.0 };
//      { SecurityId = Other "crsp_11593"
//        Signal = 5.0 }; { SecurityId = Other "crsp_11600"
//                          Signal = 5.0 }; { SecurityId = Other "crsp_11607"
//                                            Signal = 5.0 }; { SecurityId = Other "crsp_11638"
//                                                              Signal = 5.0 }; { SecurityId = Other "crsp_11663"
//                                                                                Signal = 5.0 };
//      { SecurityId = Other "crsp_11681"
//        Signal = 5.0 }; { SecurityId = Other "crsp_11689"
//                          Signal = 5.0 }; { SecurityId = Other "crsp_11691"
//                                            Signal = 5.0 }; { SecurityId = Other "crsp_11694"
//                                                              Signal = 5.0 }; { SecurityId = Other "crsp_11707"
//                                                                                Signal = 5.0 };
//      { SecurityId = Other "crsp_11731"
//        Signal = 5.0 }; { SecurityId = Other "crsp_11754"
//                          Signal = 5.0 }; { SecurityId = Other "crsp_11761"
//                                            Signal = 5.0 }; { SecurityId = Other "crsp_11762"
//                                                              Signal = 5.0 }; { SecurityId = Other "crsp_11790"
//                                                                                Signal = 5.0 };
//      { SecurityId = Other "crsp_11803"
//        Signal = 5.0 }; { SecurityId = Other "crsp_11891"
//                          Signal = 5.0 }; { SecurityId = Other "crsp_11896"
//                                            Signal = 5.0 }; { SecurityId = Other "crsp_11899"
//                                                              Signal = 5.0 }; { SecurityId = Other "crsp_11956"
//                                                                                Signal = 5.0 };
//      { SecurityId = Other "crsp_11998"
//        Signal = 5.0 }; { SecurityId = Other "crsp_12002"
//                          Signal = 5.0 }; { SecurityId = Other "crsp_12008"
//                                            Signal = 5.0 }; { SecurityId = Other "crsp_12010"
//                                                              Signal = 5.0 }; { SecurityId = Other "crsp_12079"
//                                                                                Signal = 5.0 };
//      { SecurityId = Other "crsp_12149"
//        Signal = 5.0 }; { SecurityId = Other "crsp_12173"
//                          Signal = 5.0 }; { SecurityId = Other "crsp_12195"
//                                            Signal = 5.0 }; { SecurityId = Other "crsp_12252"
//                                                              Signal = 5.0 }; { SecurityId = Other "crsp_12319"
//                                                                                Signal = 5.0 };
//      { SecurityId = Other "crsp_12320"
//        Signal = 5.0 }; { SecurityId = Other "crsp_12546"
//                          Signal = 5.0 }; { SecurityId = Other "crsp_12781"
//                                            Signal = 5.0 }; { SecurityId = Other "crsp_13290"
//                                                              Signal = 5.0 }; { SecurityId = Other "crsp_13470"
//                                                                                Signal = 5.0 };
//      { SecurityId = Other "crsp_14198"
//        Signal = 5.0 }; { SecurityId = Other "crsp_14286"
//                          Signal = 5.0 }; { SecurityId = Other "crsp_14322"
//                                            Signal = 5.0 }; { SecurityId = Other "crsp_14736"
//                                                              Signal = 5.0 }; { SecurityId = Other "crsp_14795"
//                                                                                Signal = 5.0 };
//      { SecurityId = Other "crsp_14816"
//        Signal = 5.0 }; { SecurityId = Other "crsp_15202"
//                          Signal = 5.0 }; { SecurityId = Other "crsp_15553"
//                                            Signal = 5.0 }; { SecurityId = Other "crsp_15560"
//                                                              Signal = 5.0 }; { SecurityId = Other "crsp_15721"
//                                                                                Signal = 5.0 };
//      { SecurityId = Other "crsp_16555"
//        Signal = 5.0 }; { SecurityId = Other "crsp_16600"
//                          Signal = 5.0 }; { SecurityId = Other "crsp_16715"
//                                            Signal = 5.0 }; { SecurityId = Other "crsp_16890"
//                                                              Signal = 5.0 }; { SecurityId = Other "crsp_17137"
//                                                                                Signal = 5.0 };
//      { SecurityId = Other "crsp_17743"
//        Signal = 5.0 }; { SecurityId = Other "crsp_17770"
//                          Signal = 5.0 }; { SecurityId = Other "crsp_17830"
//                                            Signal = 5.0 }; { SecurityId = Other "crsp_17929"
//                                                              Signal = 5.0 }; { SecurityId = Other "crsp_18016"
//                                                                                Signal = 5.0 };
//      { SecurityId = Other "crsp_18403"
//        Signal = 5.0 }; { SecurityId = Other "crsp_19271"
//                          Signal = 5.0 }; { SecurityId = Other "crsp_19677"
//                                            Signal = 5.0 }; { SecurityId = Other "crsp_19992"
//                                                              Signal = 5.0 }; { SecurityId = Other "crsp_20125"
//                                                                                Signal = 5.0 };
//      { SecurityId = Other "crsp_20415"
//        Signal = 5.0 }; { SecurityId = Other "crsp_20482"
//                          Signal = 5.0 }; { SecurityId = Other "crsp_20670"
//                                            Signal = 5.0 }; { SecurityId = Other "crsp_20765"
//                                                              Signal = 5.0 }; { SecurityId = Other "crsp_20853"
//                                                                                Signal = 5.0 };
//      { SecurityId = Other "crsp_21055"
//        Signal = 5.0 }; { SecurityId = Other "crsp_21135"
//                          Signal = 5.0 }; { SecurityId = Other "crsp_21186"
//                                            Signal = 5.0 }; { SecurityId = Other "crsp_21207"
//                                                              Signal = 5.0 }; { SecurityId = Other "crsp_21231"
//                                                                                Signal = 5.0 };
//      { SecurityId = Other "crsp_21282"
//        Signal = 5.0 }; { SecurityId = Other "crsp_21291"
//                          Signal = 5.0 }; { SecurityId = Other "crsp_21338"
//                                            Signal = 5.0 }; { SecurityId = Other "crsp_21371"
//                                                              Signal = 5.0 }; { SecurityId = Other "crsp_21742"
//                                                                                Signal = 5.0 };
//      { SecurityId = Other "crsp_21960"
//        Signal = 5.0 }; { SecurityId = Other "crsp_22111"
//                          Signal = 5.0 }; { SecurityId = Other "crsp_22517"
//                                            Signal = 5.0 }; { SecurityId = Other "crsp_22592"
//                                                              Signal = 5.0 }; { SecurityId = Other "crsp_22613"
//                                                                                Signal = 5.0 };
//      { SecurityId = Other "crsp_22664"
//        Signal = 5.0 }; { SecurityId = Other "crsp_22825"
//                          Signal = 5.0 }; { SecurityId = Other "crsp_22921"
//                                            Signal = 5.0 }; { SecurityId = Other "crsp_23085"
//                                                              Signal = 5.0 }; { SecurityId = Other "crsp_23115"
//                                                                                Signal = 5.0 };
//      { SecurityId = Other "crsp_23182"
//        Signal = 5.0 }; { SecurityId = Other "crsp_23297"
//                          Signal = 5.0 }; { SecurityId = Other "crsp_23536"
//                                            Signal = 5.0 }; { SecurityId = Other "crsp_23931"
//                                                              Signal = 5.0 }; { SecurityId = Other "crsp_23975"
//                                                                                Signal = 5.0 };
//      { SecurityId = Other "crsp_23990"
//        Signal = 5.0 }; { SecurityId = Other "crsp_24029"
//                          Signal = 5.0 }; { SecurityId = Other "crsp_24109"
//                                            Signal = 5.0 }; { SecurityId = Other "crsp_24205"
//                                                              Signal = 5.0 }; { SecurityId = Other "crsp_24221"
//                                                                                Signal = 5.0 }; ...] }]

// %% [markdown]
// > **Task:** Using your `formAssignedPortfolios` function, calculate quintile portfolios (5 portfolios) for your signal for August 2017. Assign the result to `aug2017Assignments5`. I've assigned type signatures to constrain the output to the correct type.
// >

// %%
let aug2017Assignments5: list<AssignedPortfolio> =
    formAssignedPortfolios (DateTime(2017,8,1)) strategyName 5

aug2017Assignments5
// Out:
// [{ PortfolioId = Indexed { Index = 1
//                            Name = "Piotroski F-Score" }
//    FormationMonth = 8/1/2017 12:00:00 AM
//    Signals =
//     [{ SecurityId = Other "crsp_76934"
//        Signal = 0.0 }; { SecurityId = Other "crsp_88173"
//                          Signal = 0.0 }; { SecurityId = Other "crsp_11368"
//                                            Signal = 1.0 }; { SecurityId = Other "crsp_11511"
//                                                              Signal = 1.0 }; { SecurityId = Other "crsp_12411"
//                                                                                Signal = 1.0 };
//      { SecurityId = Other "crsp_12413"
//        Signal = 1.0 }; { SecurityId = Other "crsp_12573"
//                          Signal = 1.0 }; { SecurityId = Other "crsp_12577"
//                                            Signal = 1.0 }; { SecurityId = Other "crsp_13652"
//                                                              Signal = 1.0 }; { SecurityId = Other "crsp_13706"
//                                                                                Signal = 1.0 };
//      { SecurityId = Other "crsp_13748"
//        Signal = 1.0 }; { SecurityId = Other "crsp_13829"
//                          Signal = 1.0 }; { SecurityId = Other "crsp_14056"
//                                            Signal = 1.0 }; { SecurityId = Other "crsp_14176"
//                                                              Signal = 1.0 }; { SecurityId = Other "crsp_14300"
//                                                                                Signal = 1.0 };
//      { SecurityId = Other "crsp_14422"
//        Signal = 1.0 }; { SecurityId = Other "crsp_14442"
//                          Signal = 1.0 }; { SecurityId = Other "crsp_14451"
//                                            Signal = 1.0 }; { SecurityId = Other "crsp_14468"
//                                                              Signal = 1.0 }; { SecurityId = Other "crsp_14532"
//                                                                                Signal = 1.0 };
//      { SecurityId = Other "crsp_14694"
//        Signal = 1.0 }; { SecurityId = Other "crsp_14790"
//                          Signal = 1.0 }; { SecurityId = Other "crsp_14935"
//                                            Signal = 1.0 }; { SecurityId = Other "crsp_15089"
//                                                              Signal = 1.0 }; { SecurityId = Other "crsp_15183"
//                                                                                Signal = 1.0 };
//      { SecurityId = Other "crsp_15184"
//        Signal = 1.0 }; { SecurityId = Other "crsp_15452"
//                          Signal = 1.0 }; { SecurityId = Other "crsp_15531"
//                                            Signal = 1.0 }; { SecurityId = Other "crsp_16463"
//                                                              Signal = 1.0 }; { SecurityId = Other "crsp_16594"
//                                                                                Signal = 1.0 };
//      { SecurityId = Other "crsp_16808"
//        Signal = 1.0 }; { SecurityId = Other "crsp_22323"
//                          Signal = 1.0 }; { SecurityId = Other "crsp_23819"
//                                            Signal = 1.0 }; { SecurityId = Other "crsp_44813"
//                                                              Signal = 1.0 }; { SecurityId = Other "crsp_68419"
//                                                                                Signal = 1.0 };
//      { SecurityId = Other "crsp_75272"
//        Signal = 1.0 }; { SecurityId = Other "crsp_75860"
//                          Signal = 1.0 }; { SecurityId = Other "crsp_76052"
//                                            Signal = 1.0 }; { SecurityId = Other "crsp_77515"
//                                                              Signal = 1.0 }; { SecurityId = Other "crsp_79022"
//                                                                                Signal = 1.0 };
//      { SecurityId = Other "crsp_80577"
//        Signal = 1.0 }; { SecurityId = Other "crsp_82281"
//                          Signal = 1.0 }; { SecurityId = Other "crsp_82747"
//                                            Signal = 1.0 }; { SecurityId = Other "crsp_83622"
//                                                              Signal = 1.0 }; { SecurityId = Other "crsp_83756"
//                                                                                Signal = 1.0 };
//      { SecurityId = Other "crsp_84052"
//        Signal = 1.0 }; { SecurityId = Other "crsp_85724"
//                          Signal = 1.0 }; { SecurityId = Other "crsp_86444"
//                                            Signal = 1.0 }; { SecurityId = Other "crsp_86812"
//                                                              Signal = 1.0 }; { SecurityId = Other "crsp_86866"
//                                                                                Signal = 1.0 };
//      { SecurityId = Other "crsp_87658"
//        Signal = 1.0 }; { SecurityId = Other "crsp_88195"
//                          Signal = 1.0 }; { SecurityId = Other "crsp_88507"
//                                            Signal = 1.0 }; { SecurityId = Other "crsp_88626"
//                                                              Signal = 1.0 }; { SecurityId = Other "crsp_88810"
//                                                                                Signal = 1.0 };
//      { SecurityId = Other "crsp_90098"
//        Signal = 1.0 }; { SecurityId = Other "crsp_90436"
//                          Signal = 1.0 }; { SecurityId = Other "crsp_90517"
//                                            Signal = 1.0 }; { SecurityId = Other "crsp_91269"
//                                                              Signal = 1.0 }; { SecurityId = Other "crsp_91355"
//                                                                                Signal = 1.0 };
//      { SecurityId = Other "crsp_91616"
//        Signal = 1.0 }; { SecurityId = Other "crsp_91900"
//                          Signal = 1.0 }; { SecurityId = Other "crsp_91907"
//                                            Signal = 1.0 }; { SecurityId = Other "crsp_92213"
//                                                              Signal = 1.0 }; { SecurityId = Other "crsp_92449"
//                                                                                Signal = 1.0 };
//      { SecurityId = Other "crsp_92456"
//        Signal = 1.0 }; { SecurityId = Other "crsp_93069"
//                          Signal = 1.0 }; { SecurityId = Other "crsp_93301"
//                                            Signal = 1.0 }; { SecurityId = Other "comp_112881_01"
//                                                              Signal = 2.0 }; { SecurityId = Other "crsp_10333"
//                                                                                Signal = 2.0 };
//      { SecurityId = Other "crsp_10463"
//        Signal = 2.0 }; { SecurityId = Other "crsp_12018"
//                          Signal = 2.0 }; { SecurityId = Other "crsp_12266"
//                                            Signal = 2.0 }; { SecurityId = Other "crsp_12350"
//                                                              Signal = 2.0 }; { SecurityId = Other "crsp_12360"
//                                                                                Signal = 2.0 };
//      { SecurityId = Other "crsp_12488"
//        Signal = 2.0 }; { SecurityId = Other "crsp_12527"
//                          Signal = 2.0 }; { SecurityId = Other "crsp_12575"
//                                            Signal = 2.0 }; { SecurityId = Other "crsp_12592"
//                                                              Signal = 2.0 }; { SecurityId = Other "crsp_12792"
//                                                                                Signal = 2.0 };
//      { SecurityId = Other "crsp_12873"
//        Signal = 2.0 }; { SecurityId = Other "crsp_12919"
//                          Signal = 2.0 }; { SecurityId = Other "crsp_13106"
//                                            Signal = 2.0 }; { SecurityId = Other "crsp_13265"
//                                                              Signal = 2.0 }; { SecurityId = Other "crsp_13280"
//                                                                                Signal = 2.0 };
//      { SecurityId = Other "crsp_13323"
//        Signal = 2.0 }; { SecurityId = Other "crsp_13327"
//                          Signal = 2.0 }; { SecurityId = Other "crsp_13521"
//                                            Signal = 2.0 }; { SecurityId = Other "crsp_13704"
//                                                              Signal = 2.0 }; { SecurityId = Other "crsp_13870"
//                                                                                Signal = 2.0 };
//      { SecurityId = Other "crsp_13879"
//        Signal = 2.0 }; { SecurityId = Other "crsp_13947"
//                          Signal = 2.0 }; { SecurityId = Other "crsp_14041"
//                                            Signal = 2.0 }; { SecurityId = Other "crsp_14044"
//                                                              Signal = 2.0 }; { SecurityId = Other "crsp_14055"
//                                                                                Signal = 2.0 };
//      { SecurityId = Other "crsp_14089"

//                                                                                Signal = 6.0 };
//      { SecurityId = Other "crsp_16341"
//        Signal = 6.0 }; { SecurityId = Other "crsp_16384"
//                          Signal = 6.0 }; { SecurityId = Other "crsp_16429"
//                                            Signal = 6.0 }; { SecurityId = Other "crsp_16432"
//                                                              Signal = 6.0 }; { SecurityId = Other "crsp_16437"
//                                                                                Signal = 6.0 };
//      { SecurityId = Other "crsp_16452"
//        Signal = 6.0 }; { SecurityId = Other "crsp_16496"
//                          Signal = 6.0 }; { SecurityId = Other "crsp_16497"
//                                            Signal = 6.0 }; { SecurityId = Other "crsp_16529"
//                                                              Signal = 6.0 }; { SecurityId = Other "crsp_16532"
//                                                                                Signal = 6.0 }; ...] };
//  { PortfolioId = Indexed { Index = 5
//                            Name = "Piotroski F-Score" }
//    FormationMonth = 8/1/2017 12:00:00 AM
//    Signals =
//     [{ SecurityId = Other "crsp_14231"
//        Signal = 7.0 }; { SecurityId = Other "crsp_14271"
//                          Signal = 7.0 }; { SecurityId = Other "crsp_14329"
//                                            Signal = 7.0 }; { SecurityId = Other "crsp_14401"
//                                                              Signal = 7.0 }; { SecurityId = Other "crsp_14408"
//                                                                                Signal = 7.0 };
//      { SecurityId = Other "crsp_14434"
//        Signal = 7.0 }; { SecurityId = Other "crsp_14452"
//                          Signal = 7.0 }; { SecurityId = Other "crsp_14478"
//                                            Signal = 7.0 }; { SecurityId = Other "crsp_14487"
//                                                              Signal = 7.0 }; { SecurityId = Other "crsp_14493"
//                                                                                Signal = 7.0 };
//      { SecurityId = Other "crsp_14503"
//        Signal = 7.0 }; { SecurityId = Other "crsp_14526"
//                          Signal = 7.0 }; { SecurityId = Other "crsp_14574"
//                                            Signal = 7.0 }; { SecurityId = Other "crsp_14599"
//                                                              Signal = 7.0 }; { SecurityId = Other "crsp_14601"
//                                                                                Signal = 7.0 };
//      { SecurityId = Other "crsp_14607"
//        Signal = 7.0 }; { SecurityId = Other "crsp_14619"
//                          Signal = 7.0 }; { SecurityId = Other "crsp_14687"
//                                            Signal = 7.0 }; { SecurityId = Other "crsp_14751"
//                                                              Signal = 7.0 }; { SecurityId = Other "crsp_14778"
//                                                                                Signal = 7.0 };
//      { SecurityId = Other "crsp_14781"
//        Signal = 7.0 }; { SecurityId = Other "crsp_14856"
//                          Signal = 7.0 }; { SecurityId = Other "crsp_14884"
//                                            Signal = 7.0 }; { SecurityId = Other "crsp_14941"
//                                                              Signal = 7.0 }; { SecurityId = Other "crsp_14942"
//                                                                                Signal = 7.0 };
//      { SecurityId = Other "crsp_14960"
//        Signal = 7.0 }; { SecurityId = Other "crsp_14985"
//                          Signal = 7.0 }; { SecurityId = Other "crsp_15014"
//                                            Signal = 7.0 }; { SecurityId = Other "crsp_15079"
//                                                              Signal = 7.0 }; { SecurityId = Other "crsp_15091"
//                                                                                Signal = 7.0 };
//      { SecurityId = Other "crsp_15133"
//        Signal = 7.0 }; { SecurityId = Other "crsp_15315"
//                          Signal = 7.0 }; { SecurityId = Other "crsp_15327"
//                                            Signal = 7.0 }; { SecurityId = Other "crsp_15339"
//                                                              Signal = 7.0 }; { SecurityId = Other "crsp_15400"
//                                                                                Signal = 7.0 };
//      { SecurityId = Other "crsp_15411"
//        Signal = 7.0 }; { SecurityId = Other "crsp_15417"
//                          Signal = 7.0 }; { SecurityId = Other "crsp_15429"
//                                            Signal = 7.0 }; { SecurityId = Other "crsp_15456"
//                                                              Signal = 7.0 }; { SecurityId = Other "crsp_15478"
//                                                                                Signal = 7.0 };
//      { SecurityId = Other "crsp_15535"
//        Signal = 7.0 }; { SecurityId = Other "crsp_15579"
//                          Signal = 7.0 }; { SecurityId = Other "crsp_15627"
//                                            Signal = 7.0 }; { SecurityId = Other "crsp_15703"
//                                                              Signal = 7.0 }; { SecurityId = Other "crsp_15720"
//                                                                                Signal = 7.0 };
//      { SecurityId = Other "crsp_15724"
//        Signal = 7.0 }; { SecurityId = Other "crsp_15797"
//                          Signal = 7.0 }; { SecurityId = Other "crsp_15859"
//                                            Signal = 7.0 }; { SecurityId = Other "crsp_16084"
//                                                              Signal = 7.0 }; { SecurityId = Other "crsp_16119"
//                                                                                Signal = 7.0 };
//      { SecurityId = Other "crsp_16156"
//        Signal = 7.0 }; { SecurityId = Other "crsp_16247"
//                          Signal = 7.0 }; { SecurityId = Other "crsp_16260"
//                                            Signal = 7.0 }; { SecurityId = Other "crsp_16268"
//                                                              Signal = 7.0 }; { SecurityId = Other "crsp_16338"
//                                                                                Signal = 7.0 };
//      { SecurityId = Other "crsp_16343"
//        Signal = 7.0 }; { SecurityId = Other "crsp_16397"
//                          Signal = 7.0 }; { SecurityId = Other "crsp_16434"
//                                            Signal = 7.0 }; { SecurityId = Other "crsp_16435"
//                                                              Signal = 7.0 }; { SecurityId = Other "crsp_16442"
//                                                                                Signal = 7.0 };
//      { SecurityId = Other "crsp_16448"
//        Signal = 7.0 }; { SecurityId = Other "crsp_16450"
//                          Signal = 7.0 }; { SecurityId = Other "crsp_16471"
//                                            Signal = 7.0 }; { SecurityId = Other "crsp_16499"
//                                                              Signal = 7.0 }; { SecurityId = Other "crsp_16528"
//                                                                                Signal = 7.0 };
//      { SecurityId = Other "crsp_16591"
//        Signal = 7.0 }; { SecurityId = Other "crsp_16632"
//                          Signal = 7.0 }; { SecurityId = Other "crsp_16682"
//                                            Signal = 7.0 }; { SecurityId = Other "crsp_16689"
//                                                              Signal = 7.0 }; { SecurityId = Other "crsp_16696"
//                                                                                Signal = 7.0 };
//      { SecurityId = Other "crsp_16736"
//        Signal = 7.0 }; { SecurityId = Other "crsp_16844"
//                          Signal = 7.0 }; { SecurityId = Other "crsp_16849"
//                                            Signal = 7.0 }; { SecurityId = Other "crsp_17073"
//                                                              Signal = 7.0 }; { SecurityId = Other "crsp_17726"
//                                                                                Signal = 7.0 };
//      { SecurityId = Other "crsp_17743"
//        Signal = 7.0 }; { SecurityId = Other "crsp_17750"
//                          Signal = 7.0 }; { SecurityId = Other "crsp_18649"
//                                            Signal = 7.0 }; { SecurityId = Other "crsp_18729"
//                                                              Signal = 7.0 }; { SecurityId = Other "crsp_18973"
//                                                                                Signal = 7.0 };
//      { SecurityId = Other "crsp_19166"
//        Signal = 7.0 }; { SecurityId = Other "crsp_20415"
//                          Signal = 7.0 }; { SecurityId = Other "crsp_20618"
//                                            Signal = 7.0 }; { SecurityId = Other "crsp_21055"
//                                                              Signal = 7.0 }; { SecurityId = Other "crsp_21785"
//                                                                                Signal = 7.0 };
//      { SecurityId = Other "crsp_21792"
//        Signal = 7.0 }; { SecurityId = Other "crsp_21928"
//                          Signal = 7.0 }; { SecurityId = Other "crsp_22293"
//                                            Signal = 7.0 }; { SecurityId = Other "crsp_22517"
//                                                              Signal = 7.0 }; { SecurityId = Other "crsp_22779"
//                                                                                Signal = 7.0 };
//      { SecurityId = Other "crsp_22825"
//        Signal = 7.0 }; { SecurityId = Other "crsp_23085"
//                          Signal = 7.0 }; { SecurityId = Other "crsp_23229"
//                                            Signal = 7.0 }; { SecurityId = Other "crsp_23393"
//                                                              Signal = 7.0 }; { SecurityId = Other "crsp_23660"
//                                                                                Signal = 7.0 };
//      { SecurityId = Other "crsp_23799"
//        Signal = 7.0 }; { SecurityId = Other "crsp_24053"
//                          Signal = 7.0 }; { SecurityId = Other "crsp_24432"
//                                            Signal = 7.0 }; { SecurityId = Other "crsp_24440"
//                                                              Signal = 7.0 }; { SecurityId = Other "crsp_24766"
//                                                                                Signal = 7.0 }; ...] }]

// %% [markdown]
// > **Task:** Assign quintile 5 to a value named `quintile5`. I've assigned type constraints to make sure the output is the correct type.
// >

// %%
let quintile5: AssignedPortfolio = 
    aug2017Assignments5.[4]

quintile5
// Out:
// { PortfolioId = Indexed { Index = 5
//                           Name = "Piotroski F-Score" }
//   FormationMonth = 8/1/2017 12:00:00 AM
//   Signals =
//    [{ SecurityId = Other "crsp_14231"
//       Signal = 7.0 }; { SecurityId = Other "crsp_14271"
//                         Signal = 7.0 }; { SecurityId = Other "crsp_14329"
//                                           Signal = 7.0 }; { SecurityId = Other "crsp_14401"
//                                                             Signal = 7.0 }; { SecurityId = Other "crsp_14408"
//                                                                               Signal = 7.0 };
//     { SecurityId = Other "crsp_14434"
//       Signal = 7.0 }; { SecurityId = Other "crsp_14452"
//                         Signal = 7.0 }; { SecurityId = Other "crsp_14478"
//                                           Signal = 7.0 }; { SecurityId = Other "crsp_14487"
//                                                             Signal = 7.0 }; { SecurityId = Other "crsp_14493"
//                                                                               Signal = 7.0 };
//     { SecurityId = Other "crsp_14503"
//       Signal = 7.0 }; { SecurityId = Other "crsp_14526"
//                         Signal = 7.0 }; { SecurityId = Other "crsp_14574"
//                                           Signal = 7.0 }; { SecurityId = Other "crsp_14599"
//                                                             Signal = 7.0 }; { SecurityId = Other "crsp_14601"
//                                                                               Signal = 7.0 };
//     { SecurityId = Other "crsp_14607"
//       Signal = 7.0 }; { SecurityId = Other "crsp_14619"
//                         Signal = 7.0 }; { SecurityId = Other "crsp_14687"
//                                           Signal = 7.0 }; { SecurityId = Other "crsp_14751"
//                                                             Signal = 7.0 }; { SecurityId = Other "crsp_14778"
//                                                                               Signal = 7.0 };
//     { SecurityId = Other "crsp_14781"
//       Signal = 7.0 }; { SecurityId = Other "crsp_14856"
//                         Signal = 7.0 }; { SecurityId = Other "crsp_14884"
//                                           Signal = 7.0 }; { SecurityId = Other "crsp_14941"
//                                                             Signal = 7.0 }; { SecurityId = Other "crsp_14942"
//                                                                               Signal = 7.0 };
//     { SecurityId = Other "crsp_14960"
//       Signal = 7.0 }; { SecurityId = Other "crsp_14985"
//                         Signal = 7.0 }; { SecurityId = Other "crsp_15014"
//                                           Signal = 7.0 }; { SecurityId = Other "crsp_15079"
//                                                             Signal = 7.0 }; { SecurityId = Other "crsp_15091"
//                                                                               Signal = 7.0 };
//     { SecurityId = Other "crsp_15133"
//       Signal = 7.0 }; { SecurityId = Other "crsp_15315"
//                         Signal = 7.0 }; { SecurityId = Other "crsp_15327"
//                                           Signal = 7.0 }; { SecurityId = Other "crsp_15339"
//                                                             Signal = 7.0 }; { SecurityId = Other "crsp_15400"
//                                                                               Signal = 7.0 };
//     { SecurityId = Other "crsp_15411"
//       Signal = 7.0 }; { SecurityId = Other "crsp_15417"
//                         Signal = 7.0 }; { SecurityId = Other "crsp_15429"
//                                           Signal = 7.0 }; { SecurityId = Other "crsp_15456"
//                                                             Signal = 7.0 }; { SecurityId = Other "crsp_15478"
//                                                                               Signal = 7.0 };
//     { SecurityId = Other "crsp_15535"
//       Signal = 7.0 }; { SecurityId = Other "crsp_15579"
//                         Signal = 7.0 }; { SecurityId = Other "crsp_15627"
//                                           Signal = 7.0 }; { SecurityId = Other "crsp_15703"
//                                                             Signal = 7.0 }; { SecurityId = Other "crsp_15720"
//                                                                               Signal = 7.0 };
//     { SecurityId = Other "crsp_15724"
//       Signal = 7.0 }; { SecurityId = Other "crsp_15797"
//                         Signal = 7.0 }; { SecurityId = Other "crsp_15859"
//                                           Signal = 7.0 }; { SecurityId = Other "crsp_16084"
//                                                             Signal = 7.0 }; { SecurityId = Other "crsp_16119"
//                                                                               Signal = 7.0 };
//     { SecurityId = Other "crsp_16156"
//       Signal = 7.0 }; { SecurityId = Other "crsp_16247"
//                         Signal = 7.0 }; { SecurityId = Other "crsp_16260"
//                                           Signal = 7.0 }; { SecurityId = Other "crsp_16268"
//                                                             Signal = 7.0 }; { SecurityId = Other "crsp_16338"
//                                                                               Signal = 7.0 };
//     { SecurityId = Other "crsp_16343"
//       Signal = 7.0 }; { SecurityId = Other "crsp_16397"
//                         Signal = 7.0 }; { SecurityId = Other "crsp_16434"
//                                           Signal = 7.0 }; { SecurityId = Other "crsp_16435"
//                                                             Signal = 7.0 }; { SecurityId = Other "crsp_16442"
//                                                                               Signal = 7.0 };
//     { SecurityId = Other "crsp_16448"
//       Signal = 7.0 }; { SecurityId = Other "crsp_16450"
//                         Signal = 7.0 }; { SecurityId = Other "crsp_16471"
//                                           Signal = 7.0 }; { SecurityId = Other "crsp_16499"
//                                                             Signal = 7.0 }; { SecurityId = Other "crsp_16528"
//                                                                               Signal = 7.0 };
//     { SecurityId = Other "crsp_16591"
//       Signal = 7.0 }; { SecurityId = Other "crsp_16632"
//                         Signal = 7.0 }; { SecurityId = Other "crsp_16682"
//                                           Signal = 7.0 }; { SecurityId = Other "crsp_16689"
//                                                             Signal = 7.0 }; { SecurityId = Other "crsp_16696"
//                                                                               Signal = 7.0 };
//     { SecurityId = Other "crsp_16736"
//       Signal = 7.0 }; { SecurityId = Other "crsp_16844"
//                         Signal = 7.0 }; { SecurityId = Other "crsp_16849"
//                                           Signal = 7.0 }; { SecurityId = Other "crsp_17073"
//                                                             Signal = 7.0 }; { SecurityId = Other "crsp_17726"
//                                                                               Signal = 7.0 };
//     { SecurityId = Other "crsp_17743"
//       Signal = 7.0 }; { SecurityId = Other "crsp_17750"
//                         Signal = 7.0 }; { SecurityId = Other "crsp_18649"
//                                           Signal = 7.0 }; { SecurityId = Other "crsp_18729"
//                                                             Signal = 7.0 }; { SecurityId = Other "crsp_18973"
//                                                                               Signal = 7.0 };
//     { SecurityId = Other "crsp_19166"
//       Signal = 7.0 }; { SecurityId = Other "crsp_20415"
//                         Signal = 7.0 }; { SecurityId = Other "crsp_20618"
//                                           Signal = 7.0 }; { SecurityId = Other "crsp_21055"
//                                                             Signal = 7.0 }; { SecurityId = Other "crsp_21785"
//                                                                               Signal = 7.0 };
//     { SecurityId = Other "crsp_21792"
//       Signal = 7.0 }; { SecurityId = Other "crsp_21928"
//                         Signal = 7.0 }; { SecurityId = Other "crsp_22293"
//                                           Signal = 7.0 }; { SecurityId = Other "crsp_22517"
//                                                             Signal = 7.0 }; { SecurityId = Other "crsp_22779"
//                                                                               Signal = 7.0 };
//     { SecurityId = Other "crsp_22825"
//       Signal = 7.0 }; { SecurityId = Other "crsp_23085"
//                         Signal = 7.0 }; { SecurityId = Other "crsp_23229"
//                                           Signal = 7.0 }; { SecurityId = Other "crsp_23393"
//                                                             Signal = 7.0 }; { SecurityId = Other "crsp_23660"
//                                                                               Signal = 7.0 };
//     { SecurityId = Other "crsp_23799"
//       Signal = 7.0 }; { SecurityId = Other "crsp_24053"
//                         Signal = 7.0 }; { SecurityId = Other "crsp_24432"
//                                           Signal = 7.0 }; { SecurityId = Other "crsp_24440"
//                                                             Signal = 7.0 }; { SecurityId = Other "crsp_24766"
//                                                                               Signal = 7.0 }; ...] }

// %% [markdown]
// > **Task:** How many stocks are in quintile 5?

// %%
let countQuintile5 = 
    quintile5.Signals
    |> List.distinct
    |> List.length

countQuintile5
// Out:
// 648

// %% [markdown]
// > **Task:** Calculate value-weights for quintile 5. The result should have type `Portfolio`.
// >

// %%
let quintile5VW: Portfolio =
    giveValueWeights getMarketCap quintile5

quintile5VW
// Out:
// { PortfolioId = Indexed { Index = 5
//                           Name = "Piotroski F-Score" }
//   FormationMonth = 8/1/2017 12:00:00 AM
//   Positions =
//    [{ SecurityId = Other "crsp_14231"
//       Weight = 0.001046385039 }; { SecurityId = Other "crsp_14271"
//                                    Weight = 0.0002073260205 }; { SecurityId = Other "crsp_14329"
//                                                                  Weight = 0.001612446484 };
//     { SecurityId = Other "crsp_14401"
//       Weight = 0.0006358262147 }; { SecurityId = Other "crsp_14408"
//                                     Weight = 0.0008046652856 }; { SecurityId = Other "crsp_14434"
//                                                                   Weight = 8.845944869e-05 };
//     { SecurityId = Other "crsp_14452"
//       Weight = 4.313042843e-06 }; { SecurityId = Other "crsp_14478"
//                                     Weight = 0.0001512561704 }; { SecurityId = Other "crsp_14487"
//                                                                   Weight = 0.0002120709118 };
//     { SecurityId = Other "crsp_14493"
//       Weight = 7.84972581e-05 }; { SecurityId = Other "crsp_14503"
//                                    Weight = 0.0004930677196 }; { SecurityId = Other "crsp_14526"
//                                                                  Weight = 0.0002038180385 };
//     { SecurityId = Other "crsp_14574"
//       Weight = 0.0001753033163 }; { SecurityId = Other "crsp_14599"
//                                     Weight = 1.837818849e-05 }; { SecurityId = Other "crsp_14601"
//                                                                   Weight = 0.000608099061 };
//     { SecurityId = Other "crsp_14607"
//       Weight = 7.223277959e-06 }; { SecurityId = Other "crsp_14619"
//                                     Weight = 4.554290942e-05 }; { SecurityId = Other "crsp_14687"
//                                                                   Weight = 0.0003363676458 };
//     { SecurityId = Other "crsp_14751"
//       Weight = 7.107275453e-05 }; { SecurityId = Other "crsp_14778"
//                                     Weight = 2.22989302e-05 }; { SecurityId = Other "crsp_14781"
//                                                                  Weight = 7.716429063e-05 };
//     { SecurityId = Other "crsp_14856"
//       Weight = 0.002249801428 }; { SecurityId = Other "crsp_14884"
//                                    Weight = 5.11742424e-05 }; { SecurityId = Other "crsp_14941"
//                                                                 Weight = 0.0003426252785 };
//     { SecurityId = Other "crsp_14942"
//       Weight = 8.258824314e-05 }; { SecurityId = Other "crsp_14960"
//                                     Weight = 6.480420341e-05 }; { SecurityId = Other "crsp_14985"
//                                                                   Weight = 0.0002506533008 };
//     { SecurityId = Other "crsp_15014"
//       Weight = 0.0003884692584 }; { SecurityId = Other "crsp_15079"
//                                     Weight = 0.0007840095851 }; { SecurityId = Other "crsp_15091"
//                                                                   Weight = 0.0003985743405 };
//     { SecurityId = Other "crsp_15133"
//       Weight = 0.0001903213692 }; { SecurityId = Other "crsp_15315"
//                                     Weight = 0.0008060512883 }; { SecurityId = Other "crsp_15327"
//                                                                   Weight = 0.0002695855345 };
//     { SecurityId = Other "crsp_15339"
//       Weight = 0.0004741214459 }; { SecurityId = Other "crsp_15400"
//                                     Weight = 0.0004418775268 }; { SecurityId = Other "crsp_15411"
//                                                                   Weight = 0.0003919847836 };
//     { SecurityId = Other "crsp_15417"
//       Weight = 4.81913384e-06 }; { SecurityId = Other "crsp_15429"
//                                    Weight = 0.0001056782824 }; { SecurityId = Other "crsp_15456"
//                                                                  Weight = 0.0007478814308 };
//     { SecurityId = Other "crsp_15478"
//       Weight = 0.00140750797 }; { SecurityId = Other "crsp_15535"
//                                   Weight = 0.0004155221233 }; { SecurityId = Other "crsp_15579"
//                                                                 Weight = 0.01325662561 };
//     { SecurityId = Other "crsp_15627"
//       Weight = 0.0003513163672 }; { SecurityId = Other "crsp_15703"
//                                     Weight = 0.001131246181 }; { SecurityId = Other "crsp_15720"
//                                                                  Weight = 0.004223546307 };
//     { SecurityId = Other "crsp_15724"
//       Weight = 0.0004677791283 }; { SecurityId = Other "crsp_15797"
//                                     Weight = 0.0008328086285 }; { SecurityId = Other "crsp_15859"
//                                                                   Weight = 0.00243898283 };
//     { SecurityId = Other "crsp_16084"
//       Weight = 0.0009932921747 }; { SecurityId = Other "crsp_16119"
//                                     Weight = 0.0001726089424 }; { SecurityId = Other "crsp_16156"
//                                                                   Weight = 0.0003550285091 };
//     { SecurityId = Other "crsp_16247"
//       Weight = 1.694252817e-05 }; { SecurityId = Other "crsp_16260"
//                                     Weight = 0.0002083769829 }; { SecurityId = Other "crsp_16268"
//                                                                   Weight = 0.0002392758215 };
//     { SecurityId = Other "crsp_16338"
//       Weight = 0.0006974517555 }; { SecurityId = Other "crsp_16343"
//                                     Weight = 0.002191479106 }; { SecurityId = Other "crsp_16397"
//                                                                  Weight = 0.0001040264225 };
//     { SecurityId = Other "crsp_16434"
//       Weight = 0.000197889914 }; { SecurityId = Other "crsp_16435"
//                                    Weight = 0.0003405592489 }; { SecurityId = Other "crsp_16442"
//                                                                  Weight = 5.871939217e-05 };
//     { SecurityId = Other "crsp_16448"
//       Weight = 9.974730235e-05 }; { SecurityId = Other "crsp_16450"
//                                     Weight = 6.478993532e-05 }; { SecurityId = Other "crsp_16471"
//                                                                   Weight = 3.89682409e-05 };
//     { SecurityId = Other "crsp_16499"
//       Weight = 0.0009270671906 }; { SecurityId = Other "crsp_16528"
//                                     Weight = 7.625438996e-06 }; { SecurityId = Other "crsp_16591"
//                                                                   Weight = 8.381321062e-05 };
//     { SecurityId = Other "crsp_16632"
//       Weight = 7.301206587e-05 }; { SecurityId = Other "crsp_16682"
//                                     Weight = 0.0002472500589 }; { SecurityId = Other "crsp_16689"
//                                                                   Weight = 0.0004736989389 };
//     { SecurityId = Other "crsp_16696"
//       Weight = 0.0002993093546 }; { SecurityId = Other "crsp_16736"
//                                     Weight = 0.001223619216 }; { SecurityId = Other "crsp_16844"
//                                                                  Weight = 7.127648181e-05 };
//     { SecurityId = Other "crsp_16849"
//       Weight = 1.095089813e-05 }; { SecurityId = Other "crsp_17073"
//                                     Weight = 3.550737155e-05 }; { SecurityId = Other "crsp_17726"
//                                                                   Weight = 0.001288470634 };
//     { SecurityId = Other "crsp_17743"
//       Weight = 0.001306648859 }; { SecurityId = Other "crsp_17750"
//                                    Weight = 0.007042399285 }; { SecurityId = Other "crsp_18649"
//                                                                 Weight = 0.0006402747043 };
//     { SecurityId = Other "crsp_18729"
//       Weight = 0.01020232259 }; { SecurityId = Other "crsp_18973"
//                                   Weight = 0.0002575060359 }; { SecurityId = Other "crsp_19166"
//                                                                 Weight = 0.001869704345 };
//     { SecurityId = Other "crsp_20415"
//       Weight = 0.001373033234 }; { SecurityId = Other "crsp_20618"
//                                    Weight = 0.0003063923947 }; { SecurityId = Other "crsp_21055"
//                                                                  Weight = 6.700063695e-05 };
//     { SecurityId = Other "crsp_21785"
//       Weight = 3.466082061e-06 }; { SecurityId = Other "crsp_21792"
//                                     Weight = 0.002064105938 }; { SecurityId = Other "crsp_21928"
//                                                                  Weight = 0.0007249644543 };
//     { SecurityId = Other "crsp_22293"
//       Weight = 0.004199625696 }; { SecurityId = Other "crsp_22517"
//                                    Weight = 0.004351183744 }; { SecurityId = Other "crsp_22779"
//                                                                 Weight = 0.002317313084 };
//     { SecurityId = Other "crsp_22825"
//       Weight = 0.000548054241 }; { SecurityId = Other "crsp_23085"
//                                    Weight = 0.001395155037 }; { SecurityId = Other "crsp_23229"
//                                                                 Weight = 0.002213167951 };
//     { SecurityId = Other "crsp_23393"
//       Weight = 0.002023838086 }; { SecurityId = Other "crsp_23660"
//                                    Weight = 0.002317683369 }; { SecurityId = Other "crsp_23799"
//                                                                 Weight = 5.975097634e-05 };
//     { SecurityId = Other "crsp_24053"
//       Weight = 0.001178745842 }; { SecurityId = Other "crsp_24432"
//                                    Weight = 0.001070054553 }; { SecurityId = Other "crsp_24440"
//                                                                 Weight = 0.001153303719 };
//     { SecurityId = Other "crsp_24766"
//       Weight = 0.007664352987 }; ...] }

// %% [markdown]
// > **Task:** Plot a histogram of the position weights for the stocks in quintile 5.

// %%
let weights = [for i in quintile5VW.Positions do i.Weight]

let Histogram =
    weights
    |> Chart.Histogram
// Out:
// <div id="85fe1a40-7eb6-4a05-854d-8f75d93a81a0"><!-- Plotly chart will be drawn inside this DIV --></div>
// <script type="text/javascript">
//
//             var renderPlotly_85fe1a407eb64a05854d8f75d93a81a0 = function() {
//             var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-2.6.3.min'}}) || require;
//             fsharpPlotlyRequire(['plotly'], function(Plotly) {
//
//             var data = [{"type":"histogram","x":[0.001046385038737354,0.00020732602045903497,0.0016124464841997365,0.0006358262147409429,0.0008046652856404191,8.845944868986399E-05,4.313042843177963E-06,0.00015125617036949504,0.00021207091180949598,7.849725809728544E-05,0.0004930677196075305,0.00020381803848913482,0.00017530331631760413,1.8378188487236763E-05,0.0006080990610473859,7.223277958809915E-06,4.5542909421974317E-05,0.00033636764584510435,7.10727545340012E-05,2.2298930203264858E-05,7.716429063281796E-05,0.0022498014278615587,5.1174242402278915E-05,0.00034262527851372407,8.258824314205756E-05,6.480420341047173E-05,0.0002506533007772439,0.00038846925840824924,0.0007840095850667146,0.00039857434045046644,0.00019032136920832008,0.0008060512882959935,0.00026958553447305964,0.0004741214459061806,0.0004418775268462069,0.0003919847835805092,4.819133839745864E-06,0.0001056782824283232,0.0007478814308078456,0.00140750796976657,0.00041552212329580074,0.013256625608081524,0.00035131636715059916,0.0011312461812066855,0.004223546307041278,0.0004677791282559303,0.0008328086284989527,0.0024389828297786027,0.0009932921747092373,0.0001726089424052206,0.0003550285091162667,1.694252817111964E-05,0.00020837698285154646,0.00023927582151232383,0.0006974517555001111,0.002191479106251517,0.00010402642249205974,0.00019788991400089114,0.00034055924894577414,5.871939216524606E-05,9.974730235450243E-05,6.47899353157186E-05,3.89682409036786E-05,0.0009270671905666224,7.625438996100531E-06,8.381321062166015E-05,7.301206587359212E-05,0.0002472500588679754,0.0004736989389133236,0.0002993093546386998,0.0012236192162239734,7.127648180566306E-05,1.0950898133438975E-05,3.550737154623847E-05,0.0012884706341658174,0.001306648859045899,0.007042399284808034,0.0006402747042985299,0.010202322592125381,0.0002575060359345035,0.0018697043448591944,0.001373033234236321,0.0003063923947354965,6.700063694508874E-05,3.4660820608974173E-06,0.002064105937932523,0.000724964454286772,0.004199625696034336,0.0043511837444268125,0.0023173130839697453,0.0005480542409984906,0.001395155037041993,0.002213167950634701,0.0020238380862052556,0.0023176833688172923,5.975097634165395E-05,0.0011787458415795855,0.0010700545529360467,0.0011533037191902265,0.007664352987194926,0.0008058353789844448,0.00040076077649629473,1.176638826604625E-05,3.941080628019346E-05,0.005152361814502079,0.009879312895383702,0.001623695780291989,0.016495203168963694,0.0006322345355325573,0.0003598203706652966,0.006923069494975624,4.28711319957318E-06,8.480383066761479E-05,0.0009975146189069506,0.00403372618158699,8.44075860922843E-05,2.5865163839306197E-05,2.244587875928807E-06,0.0028460737038736245,0.0015651818354285854,0.0008132672087696255,0.005123706929130496,3.0091907173941483E-05,0.00041005897670236507,0.003973402509574295,0.0005120712293977422,0.0008434603379998548,0.0023920729706202646,0.0005441935053688787,0.0001771120600728339,7.363086681397101E-05,0.0003468791052612901,0.0035656069217948304,0.0015418365492025686,0.001346995720815226,0.00011954204541910808,0.0004004115141805601,0.00019899882199724009,0.0023757216074861654,1.938534762879826E-05,1.1294642546762263E-05,1.236879364399218E-05,0.0005168756475591531,2.0818400216677564E-05,0.000903794094955102,0.00024585559370433245,0.0003564768708061911,0.00018461879544850055,5.7278765632322084E-05,0.0005139231492046476,0.001986869611850483,0.0012805443688661915,0.00024341447663960312,0.00012844404879276065,0.00010032272281849796,0.0003253520315051121,0.00018400066810354796,0.0004498318224900445,0.00013087450045618507,0.0001656862275037933,0.03770459088425227,2.391725076600563E-05,0.002181358146336058,5.863398823161386E-06,0.00038382078012714577,0.005274865142835818,3.361172253112521E-05,7.0602048815414565E-06,0.0005116934322117773,1.2996885220664087E-05,0.0013738692141570922,0.003825581131299263,2.7646630558468693E-05,0.0010013831399618542,0.0018698108164047485,0.0006084902501769441,0.01210867905140838,0.0010413765837287588,0.001016279346165189,5.26067113 ...

// %% [markdown]
// >
//
// > **Task:** Calculate the minimum, 5th percentile, 50th percentile, 95th percentile, and maxium of the position weights for quintile 5.
// >

// %%
let minimum =
    weights
    |> List.min

let maximum =
    weights
    |> List.max

printfn "The minimum is equal to %f" minimum
printfn "The maximum is equal to %f" maximum
// Out:
// The minimum is equal to 0.000000
// The maximum is equal to 0.076159

// %%
let percentiles = [0.05; 0.5; 0.95]

let weightInArrayForm =
    weights
    |> List.toArray

let percentilesWeights = 
    [for p in percentiles do
        Quantile.compute p weightInArrayForm]

percentilesWeights
// Out:
// [6.040153243e-06; 0.0003399500363; 0.006313485887]

// %% [markdown]
// > **Task:** Calculate the total weight put in quintile 5's top 10 positions when using value weights. How does this compare to the total weight of the top 10 positions if you used equal weights instead of value weights?
// >

// %%
let TopVW = 
    weights
    |> List.sortDescending
    |> List.truncate 10
    |> List.sum

let TopEW =
    10/648

// %%
TopVW
// Out:
// 0.348673364

// %%
weights.Length
// Out:
// 648

// %%
TopEW
// Out:
// 0

// %% [markdown]
// TExt here
